# %% [markdown]
# ### Importing necessary python libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import imageio
# %matplotlib inline

# %% [markdown]
# ### Reading the CSV and Excel files and creating pandas dataframes

# %%
fertility = pd.read_csv('/home/arman/github_portfolio_spiced/Project_01_ Visual Data Analysis/gapminder_total_fertility.csv', index_col = 0)
life_expectancy = pd.read_excel('/home/arman/github_portfolio_spiced/Project_01_ Visual Data Analysis/gapminder_lifeexpectancy.xlsx', index_col = 0)

# %% [markdown]
# #### Now let's take a look at the created dataframes

# %%
fertility.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 260 entries, Abkhazia to Åland
# Columns: 216 entries, 1800 to 2015
# dtypes: float64(216)
# memory usage: 440.8+ KB

# %%
fertility
# Out:
#                        1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# Total fertility rate
# Abkhazia                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria                6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
# ...                     ...   ...   ...   ...   ...   ...   ...   ...   ...
# Yugoslavia              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zambia                 6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71
# Zimbabwe               6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75
# Åland                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Åland                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# ...

# %%
life_expectancy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 260 entries, Abkhazia to South Sudan
# Columns: 217 entries, 1800.0 to 2016.0
# dtypes: float64(217)
# memory usage: 442.8+ KB

# %%
life_expectancy
# Out:
#                        1800.0  1801.0  1802.0  1803.0  1804.0  1805.0  1806.0  \
# Life expectancy
# Abkhazia                  NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Afghanistan             28.21   28.20   28.19   28.18   28.17   28.16   28.15
# Akrotiri and Dhekelia     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Albania                 35.40   35.40   35.40   35.40   35.40   35.40   35.40
# Algeria                 28.82   28.82   28.82   28.82   28.82   28.82   28.82
# ...                       ...     ...     ...     ...     ...     ...     ...
# Yugoslavia                NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Zambia                  32.60   32.60   32.60   32.60   32.60   32.60   32.60
# Zimbabwe                33.70   33.70   33.70   33.70   33.70   33.70   33.70
# Åland                     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# South Sudan             26.67   26.67   26.67   26.67   26.67   26.67   26.67
#
# ...

# %% [markdown]
# ### Project milestone:  Draw a histogram of life expectancies for the year 2015.

# %%
life_expectancy[2015].hist(bins=5, facecolor='#ff0000', alpha=0.75, histtype='bar',)
plt.title('Life expectancy distribution in 2015')
plt.xlabel('Age')
plt.ylabel('frequency')
plt.axis([40.0, 90.0, 0.0, 80.0])
plt.savefig('histogram_2015.png', dpi=150)

# %% [markdown]
# ### Project milestone: Draw a bar plot showing fertility and population (for Germany, Brazil, Kenya) in three slected years (1950, 1975, 2000)
# - Draw a bar plot using the years as bar groups
# - Modify the size of the diagram
# - Transpose the DataFrame and see how the grouping of bars changes

# %%
df = fertility[['1950', '1975', '2000']]
df
# Out:
#                        1950  1975  2000
# Total fertility rate
# Abkhazia                NaN   NaN   NaN
# Afghanistan            7.67  7.67  7.73
# Akrotiri and Dhekelia   NaN   NaN   NaN
# Albania                5.80  4.39  2.38
# Algeria                7.65  7.42  2.51
# ...                     ...   ...   ...
# Yugoslavia              NaN   NaN   NaN
# Zambia                 6.71  7.44  6.07
# Zimbabwe               6.75  7.40  4.07
# Åland                   NaN   NaN   NaN
# Åland                   NaN   NaN   NaN
#
# [260 rows x 3 columns]

# %%
df = df.loc[['Germany', 'India', 'Bulgaria', 'Kenya']]
df
# Out:
#                       1950  1975  2000
# Total fertility rate
# Germany               2.07  1.56  1.35
# India                 5.89  5.08  3.15
# Bulgaria              2.66  2.19  1.18
# Kenya                 7.36  7.84  5.01

# %%
df.plot.bar(figsize=(8,6))
# Out:
# <AxesSubplot:xlabel='Total fertility rate'>

# %%
df.transpose().plot.bar(figsize=(8,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Project milestone: Animated Scatterplot
# #### In this part, the famous Hans Rosling's animation will be reproduced
# ##### 1. Multiple dataframes will be created using fertility, life expectancy and population. then these dataframes will be transfered into long format with similar number of rows and then will be merged
# ##### 2. For each year a separate scatter plot will be created
# ##### 3. The created scatter plots will be combined to create an animated gif (this method was used to practice data wrangling and visualization. keep in mind that we can also make this animation much faster and easier using the new library called PlotlyExpress that is very simple, fast and easy to use to build Interactive Visualizations.

# %%
print(life_expectancy.shape)
print(fertility.shape)
# Out:
# (260, 217)
# (260, 216)

# %%
life_expectancy.columns
# Out:
# Float64Index([1800.0, 1801.0, 1802.0, 1803.0, 1804.0, 1805.0, 1806.0, 1807.0,
#               1808.0, 1809.0,
#               ...
#               2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0,
#               2015.0, 2016.0],
#              dtype='float64', length=217)

# %%
fertility.columns
# Out:
# Index(['1800', '1801', '1802', '1803', '1804', '1805', '1806', '1807', '1808',
#        '1809',
#        ...
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015'],
#       dtype='object', length=216)

# %%
# In the fertility dataframe, the years have a type of 'String' while in the life_expectancy, data frame, they are float!
# First, both need to have the same data type!
fertility.columns = fertility.columns.astype(int)

# %%
fertility.columns
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015],
#            dtype='int64', length=216)

# %%
# now both have the same data type

# %%
fertility.index
# Out:
# Index(['Abkhazia', 'Afghanistan', 'Akrotiri and Dhekelia', 'Albania',
#        'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Anguilla',
#        'Antigua and Barbuda',
#        ...
#        'Vietnam', 'Virgin Islands (U.S.)', 'North Yemen (former)',
#        'South Yemen (former)', 'Yemen', 'Yugoslavia', 'Zambia', 'Zimbabwe',
#        'Åland', 'Åland'],
#       dtype='object', name='Total fertility rate', length=260)

# %%
fertility.index.name = 'country'
fertility
# Out:
#                        1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# country
# Abkhazia                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria                6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
# ...                     ...   ...   ...   ...   ...   ...   ...   ...   ...
# Yugoslavia              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zambia                 6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71
# Zimbabwe               6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75
# Åland                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Åland                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# ...

# %%
fertility = fertility.reset_index()
fertility
# Out:
#                    country  1800  1801  1802  1803  1804  1805  1806  1807  \
# 0                 Abkhazia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1              Afghanistan  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# 2    Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3                  Albania  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# 4                  Algeria  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
# ..                     ...   ...   ...   ...   ...   ...   ...   ...   ...
# 255             Yugoslavia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 256                 Zambia  6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71
# 257               Zimbabwe  6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75
# 258                  Åland   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 259                  Åland   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# ...

# %%
df1 = fertility.melt(id_vars='country', var_name='year', value_name='fertility_rate')
df1
# Out:
#                      country  year  fertility_rate
# 0                   Abkhazia  1800             NaN
# 1                Afghanistan  1800            7.00
# 2      Akrotiri and Dhekelia  1800             NaN
# 3                    Albania  1800            4.60
# 4                    Algeria  1800            6.99
# ...                      ...   ...             ...
# 56155             Yugoslavia  2015             NaN
# 56156                 Zambia  2015            5.59
# 56157               Zimbabwe  2015            3.35
# 56158                  Åland  2015             NaN
# 56159                  Åland  2015             NaN
#
# [56160 rows x 3 columns]

# %%
#Now we do the same with the other dataframes
life_expectancy
# Out:
#                        1800.0  1801.0  1802.0  1803.0  1804.0  1805.0  1806.0  \
# Life expectancy
# Abkhazia                  NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Afghanistan             28.21   28.20   28.19   28.18   28.17   28.16   28.15
# Akrotiri and Dhekelia     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Albania                 35.40   35.40   35.40   35.40   35.40   35.40   35.40
# Algeria                 28.82   28.82   28.82   28.82   28.82   28.82   28.82
# ...                       ...     ...     ...     ...     ...     ...     ...
# Yugoslavia                NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Zambia                  32.60   32.60   32.60   32.60   32.60   32.60   32.60
# Zimbabwe                33.70   33.70   33.70   33.70   33.70   33.70   33.70
# Åland                     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# South Sudan             26.67   26.67   26.67   26.67   26.67   26.67   26.67
#
# ...

# %%
life_expectancy.index.name = 'country'
life_expectancy = life_expectancy.reset_index()
df2 = life_expectancy.melt(id_vars='country', var_name='year', value_name='life_expectancy')
df2
# Out:
#                      country    year  life_expectancy
# 0                   Abkhazia  1800.0              NaN
# 1                Afghanistan  1800.0            28.21
# 2      Akrotiri and Dhekelia  1800.0              NaN
# 3                    Albania  1800.0            35.40
# 4                    Algeria  1800.0            28.82
# ...                      ...     ...              ...
# 56415             Yugoslavia  2016.0              NaN
# 56416                 Zambia  2016.0            57.10
# 56417               Zimbabwe  2016.0            61.69
# 56418                  Åland  2016.0              NaN
# 56419            South Sudan  2016.0            56.10
#
# [56420 rows x 3 columns]

# %%
merged_df = df1.merge(df2)

# %%
merged_df
# Out:
#                      country  year  fertility_rate  life_expectancy
# 0                   Abkhazia  1800             NaN              NaN
# 1                Afghanistan  1800            7.00            28.21
# 2      Akrotiri and Dhekelia  1800             NaN              NaN
# 3                    Albania  1800            4.60            35.40
# 4                    Algeria  1800            6.99            28.82
# ...                      ...   ...             ...              ...
# 56155             Yugoslavia  2015             NaN              NaN
# 56156                 Zambia  2015            5.59            56.70
# 56157               Zimbabwe  2015            3.35            59.30
# 56158                  Åland  2015             NaN              NaN
# 56159                  Åland  2015             NaN              NaN
#
# [56160 rows x 4 columns]

# %%
#A look into population data shows that it has 275 rows. i want it to have the same number of rows as other two dataframes (i. e. 260). 
# therefore i add an argument while reading the excel file (i. e. nrows =260)

# %%
population = pd.read_excel('/home/arman/github_portfolio_spiced/Project_01_ Visual Data Analysis/gapminder_population.xlsx' , index_col=0, nrows=260)

# %%
population
# Out:
#                           1800.0     1810.0     1820.0     1830.0     1840.0  \
# Total population
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3280000.0  3280000.0  3323519.0  3448982.0  3625022.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
# Albania                 410445.0   423591.0   438671.0   457234.0   478227.0
# Algeria                2503218.0  2595056.0  2713079.0  2880355.0  3082721.0
# ...                          ...        ...        ...        ...        ...
# Yugoslavia                   NaN        NaN        NaN        NaN        NaN
# Zambia                  747000.0   747000.0   747000.0   747000.0   747000.0
# Zimbabwe               1085814.0  1085814.0  1106634.0  1167259.0  1253642.0
# Åland                        NaN        NaN        NaN        NaN        NaN
# South Sudan            1027378.0  1041076.0  1063732.0  1103246.0  1153401.0
#
# ...

# %%
population.index.name = 'country'
population = population.reset_index()
df3 = population.melt(id_vars='country', var_name='year', value_name='population')
df3
# Out:
#                      country    year  population
# 0                   Abkhazia  1800.0         NaN
# 1                Afghanistan  1800.0   3280000.0
# 2      Akrotiri and Dhekelia  1800.0         NaN
# 3                    Albania  1800.0    410445.0
# 4                    Algeria  1800.0   2503218.0
# ...                      ...     ...         ...
# 21055             Yugoslavia  2015.0         NaN
# 21056                 Zambia  2015.0  16211767.0
# 21057               Zimbabwe  2015.0  15602751.0
# 21058                  Åland  2015.0         NaN
# 21059            South Sudan  2015.0  12339812.0
#
# [21060 rows x 3 columns]

# %%
merged_df_2= merged_df.merge(df3)
merged_df_2
# Out:
#                      country  year  fertility_rate  life_expectancy  \
# 0                   Abkhazia  1800             NaN              NaN
# 1                Afghanistan  1800            7.00            28.21
# 2      Akrotiri and Dhekelia  1800             NaN              NaN
# 3                    Albania  1800            4.60            35.40
# 4                    Algeria  1800            6.99            28.82
# ...                      ...   ...             ...              ...
# 20974             Yugoslavia  2015             NaN              NaN
# 20975                 Zambia  2015            5.59            56.70
# 20976               Zimbabwe  2015            3.35            59.30
# 20977                  Åland  2015             NaN              NaN
# 20978                  Åland  2015             NaN              NaN
#
#        population
# 0             NaN
# 1       3280000.0
# 2             NaN
# 3        410445.0
# 4       2503218.0
# ...           ...
# ...

# %%
# Now lets's  make a scatter plot for year 2000
df_subset = merged_df_2.loc[merged_df_2['year'] == 2000]
df_subset
# Out:
#                      country  year  fertility_rate  life_expectancy  \
# 16835               Abkhazia  2000             NaN              NaN
# 16836            Afghanistan  2000            7.73             50.1
# 16837  Akrotiri and Dhekelia  2000             NaN              NaN
# 16838                Albania  2000            2.38             74.7
# 16839                Algeria  2000            2.51             73.3
# ...                      ...   ...             ...              ...
# 17089             Yugoslavia  2000             NaN              NaN
# 17090                 Zambia  2000            6.07             44.8
# 17091               Zimbabwe  2000            4.07             47.9
# 17092                  Åland  2000             NaN             80.0
# 17093                  Åland  2000             NaN             80.0
#
#        population
# 16835         NaN
# 16836  19701940.0
# 16837     15157.0
# 16838   3121965.0
# 16839  31183658.0
# ...           ...
# ...

# %%
sns.scatterplot(x='fertility_rate', y= 'life_expectancy',data=df_subset, alpha=0.6)
# Out:
# <AxesSubplot:xlabel='fertility_rate', ylabel='life_expectancy'>

# %%
# Now let's try to give it some colors and change the size of dots based on the population
cmap = plt.get_cmap('tab20', lut = len(df_subset)).colors

# %%
df_subset.plot.scatter('fertility_rate', 'life_expectancy', s=0.8, c=cmap)
# Out:
# <AxesSubplot:xlabel='fertility_rate', ylabel='life_expectancy'>

# %%
df_subset.plot.scatter('fertility_rate', 'life_expectancy', s=df_subset['population']*0.000001, c=cmap)
# Out:
# <AxesSubplot:xlabel='fertility_rate', ylabel='life_expectancy'>

# %%
# Ok it works! Nice!

# %% [markdown]
# #### now for preparing an animated scatter plot showing correlation between fertility_rate and life_expectancy (between 1960 to 2015 - before that there are many missing data), we have to create one scatter plot for each year and save them and then glue them together to make a gif!!

# %%
#for_1960_2015_df = merged_df_2.loc[(merged_df_2['year'] <= 2015) & (merged_df_2['year'] >= 1960)]
#for_1960_2015_df

# %%
#create the animation
for i in range(1960,2015):
    for_1960_2015_df = merged_df_2.loc[merged_df_2['year'] == i]
    #plt.figure(figsize = (20,13))
    for_1960_2015_df.plot.scatter('fertility_rate', 'life_expectancy', s=df_subset['population']*0.000001, c=cmap);
    plt.axis([1, 10, 20, 80])
    plt.xlabel('Fertility')
    plt.ylabel('Life Expectancy (Years)')
    plt.title(str(i))
    plt.savefig('graph_'+str(i)+'.png')
    plt.close()
    
images = []
for i in range(1960, 2015):
    filename = 'graph_{}.png'.format(i)
    images.append(imageio.imread(filename))

imageio.mimsave('Annimated_Plot.gif', images, fps=10)
